# %%
from pathlib import Path
PROJECT_ROOT = Path("/Users/madlineceleste/Desktop/agent/gpudrive")
PROJECT_ROOT
# Out:
# PosixPath('/Users/madlineceleste/Desktop/agent/gpudrive')

# %% [markdown]
# ## Structure
# - `src/`: C++ simulator implementation
# - `gpudrive/env/`: Python environment wrappers, and this is the layer that RL python code interacts with
# - `baselines`: Example RL training code, including PPO integrations
# - `tests/`: Small examples
